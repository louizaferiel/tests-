# %% [markdown]
# ## Quiz #0203

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Read in the data.

# %%
# Go to the directory where the data file is located. 
# os.chdir(r'~~')                # Please, replace the path with your own.

# %%
df = pd.read_csv('data_sales.csv', header='infer')

# %%
df.shape
# Out:
# (43, 5)

# %%
df.head(5)
# Out:
#           Date   Region     Item  UnitPrice  Units
# 0   4-Jul-2014     East  Pen Set       4.99     62
# 1  12-Jul-2014     East   Binder       1.99     29
# 2  21-Jul-2014  Central  Pen Set      12.49     55
# 3  29-Jul-2014     East   Binder      19.99     81
# 4   7-Aug-2014  Central  Pen Set      23.95     42

# %% [markdown]
# #### Answer the following questions.

# %% [markdown]
# 1). Append a new variable $Amount = UnitPric \times Units$.

# %%
df['Amount'] =df['UnitPrice'] * df['Units']
df.head()
# Out:
#           Date   Region     Item  UnitPrice  Units   Amount
# 0   4-Jul-2014     East  Pen Set       4.99     62   309.38
# 1  12-Jul-2014     East   Binder       1.99     29    57.71
# 2  21-Jul-2014  Central  Pen Set      12.49     55   686.95
# 3  29-Jul-2014     East   Binder      19.99     81  1619.19
# 4   7-Aug-2014  Central  Pen Set      23.95     42  1005.90

# %% [markdown]
# 2). Average unit price for each region. Use the groupby() method.

# %%
df.groupby('Region').UnitPrice.mean()
# Out:
# Region
# Central    18.018750
# East        9.143846
# West       53.658333
# Name: UnitPrice, dtype: float64

# %% [markdown]
# 3). Average unit price for each region. Use the pivot_table() method.

# %%
pd.pivot_table(df, index=["Region"], columns=["UnitPrice"] , aggfunc=np.mean)
# Out:
#             Amount                               ...  Units
# UnitPrice   1.29     1.99    2.99        4.99    ... 19.99  23.95  125.00 275.00
# Region                                           ...
# Central    45.4725  140.295     NaN  285.855714  ...   57.0   42.0    3.5    NaN
# East           NaN  123.380     NaN  256.486000  ...   48.0    NaN    NaN    NaN
# West           NaN  107.460  167.44         NaN  ...   32.0    NaN    NaN    3.0
#
# [3 rows x 24 columns]

# %% [markdown]
# 4). Average unit price and units for each region in one code sentence. Use the groupby() method.

# %%
df.groupby("Region").agg({'UnitPrice':['mean'],'Units':['mean']})
# Out:
#          UnitPrice      Units
#               mean       mean
# Region
# Central  18.018750  49.958333
# East      9.143846  53.153846
# West     53.658333  38.500000

# %% [markdown]
# 5). Average unit price and units for each region in one code sentence. Use the pivot_table() method.

# %%
pd.pivot_table(df, index=["Region"], columns=["Units" , "UnitPrice"] , aggfunc=np.mean)
# Out:
#           Amount                       ...
# Units         2      3      4      5   ...     90       94      95      96
# UnitPrice 125.00 275.00 4.99   125.00  ... 4.99     19.99   1.99    4.99
# Region                                 ...
# Central    250.0    NaN    NaN  625.0  ...  449.1  1879.06     NaN  479.04
# East         NaN    NaN  19.96    NaN  ...    NaN      NaN  189.05  479.04
# West         NaN  825.0    NaN    NaN  ...    NaN      NaN     NaN     NaN
#
# [3 rows x 41 columns]

# %% [markdown]
# 6). Total units for each region and item type in one code sentence. Use the pivot_table() method. Fill the missing values with 0.

# %%
pd.pivot_table(df, index=["Units"], columns=["Item" , "Region"] , aggfunc=np.sum, fill_value=0)
# Out:
#          Amount                            ... UnitPrice
# Item     Binder                      Desk  ...   Pen Set  Pencil
# Region  Central     East     West Central  ...      East Central  East  West
# Units                                      ...
# 2          0.00     0.00     0.00     250  ...      0.00    0.00  0.00  0.00
# 3          0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 4          0.00    19.96     0.00       0  ...      0.00    0.00  0.00  0.00
# 5          0.00     0.00     0.00     625  ...      0.00    0.00  0.00  0.00
# 7          0.00     0.00   139.93       0  ...      0.00    1.29  0.00  0.00
# 11        54.89     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 14         0.00     0.00     0.00       0  ...      0.00    1.29  0.00  0.00
# 15         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 16         0.00     0.00     0.00       0  ...     15.99    0.00  0.00  0.00
# 27         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 28       391.44     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 29         0.00    57.71     0.00       0  ...      0.00    0.00  0.00  0.00
# 32         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  1.99
# 35         0.00     0.00     0.00       0  ...      0.00    0.00  4.99  0.00
# 36         0.00     0.00     0.00       0  ...      0.00    4.99  0.00  0.00
# 42         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 46       413.54     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 50       999.50     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 53         0.00     0.00     0.00       0  ...      0.00    1.29  0.00  0.00
# 55         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 56         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  2.99
# 57         0.00     0.00  1139.43       0  ...      0.00    0.00  0.00  0.00
# 60         0.00   838.80     0.00       0  ...      0.00    0.00  0.00  0.00
# 62         0.00     0.00     0.00       0  ...      4.99    0.00  0.00  0.00
# 64         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 66         0.00     0.00     0.00       0  ...      0.00    1.99  0.00  0.00
# 67         0.00     0.00     0.00       0  ...      0.00    1.29  0.00  0.00
# 74         0.00     0.00     0.00       0  ...     15.99    0.00  0.00  0.00
# 75         0.00     0.00     0.00       0  ...      0.00    1.99  0.00  0.00
# 76         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 80       719.20     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 81         0.00  1619.19     0.00       0  ...      0.00    0.00  0.00  0.00
# 87      1305.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 90         0.00     0.00     0.00       0  ...      0.00    9.98  0.00  0.00
# 94      1879.06     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
# 95         0.00     0.00     0.00       0  ...      0.00    0.00  1.99  0.00
# 96         0.00     0.00     0.00       0  ...      0.00    0.00  0.00  0.00
#
# [37 rows x 26 columns]

# %% [markdown]
# 7). Total sales amount for each region and item type in one code sentence. Use the pivot_table() method. Fill the missing values with 0.

# %%
pd.pivot_table(df, index=["Amount"], columns=["Item" , "Region"] , aggfunc=np.sum, fill_value=0)
# Out:
#         UnitPrice                             ...   Units
# Item       Binder                  Desk       ... Pen Set       Pencil
# Region    Central   East   West Central West  ... Central East Central East West
# Amount                                        ...
# 9.03         0.00   0.00   0.00       0    0  ...       0    0       7    0    0
# 18.06        0.00   0.00   0.00       0    0  ...       0    0      14    0    0
# 19.96        0.00   4.99   0.00       0    0  ...       0    0       0    0    0
# 54.89        4.99   0.00   0.00       0    0  ...       0    0       0    0    0
#